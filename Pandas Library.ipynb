# %%
# Wider the size of the Notebook

from IPython.core.display import display, HTML
display(HTML("<style>.container {width:90% !important;}</style>"))
# Out:
# <style>.container {width:90% !important;}</style>

# %%
import pandas as pd
#data = pd.read_csv('happiness_with_continent.csv')
data = pd.read_csv('https://raw.githubusercontent.com/FBosler/you-datascientist/master/happiness_with_continent.csv')
data
#data.columns

pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 10)

data.shape
data.columns

data.index
#data.info()
data.describe()
# Out:
#               Year  Life Ladder  Log GDP per capita  Social support  \
# count  1704.000000  1704.000000         1676.000000     1691.000000
# mean   2012.332160     5.437155            9.222456        0.810570
# std       3.688072     1.121149            1.185794        0.119210
# min    2005.000000     2.661718            6.457201        0.290184
# 25%    2009.000000     4.610970            8.304428        0.747512
# 50%    2012.000000     5.339557            9.406206        0.833098
# 75%    2015.000000     6.273522           10.193060        0.904432
# max    2018.000000     8.018934           11.770276        0.987343
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       1676.000000                   1675.000000
# mean                          63.111971                      0.733829
# std                            7.583622                      0.144115
# min                           32.299999                      0.257534
# ...

# %%
pd.read_clipboard()
# Out:
#                   name  mana_cost                  card_type  \
# 0          Black Lotus          0                   Artifact
# 1           Black Vise          1                   Artifact
# 2      Celestial Prism          3                   Artifact
# 3            Chaos Orb          2                   Artifact
# 4      Clockwork Beast          6  Artifact Creature — Beast
# 5          Conservator          4                   Artifact
# 6        Copper Tablet          2                   Artifact
# 7          Crystal Rod          1                   Artifact
# 8       Cyclopean Tomb          4                   Artifact
# 9           Dingus Egg          4                   Artifact
# 10  Disrupting Scepter          3                   Artifact
# 11          Forcefield          3                   Artifact
# 12   Gauntlet of Might          4                   Artifact
# 13     Glasses of Urza          1                   Artifact
# ...

# %%
# Sortring -- data.sortvalues()

data.sort_values(by ='Year')
data.sort_values(by=['Year', 'Country name'])
data.sort_values(by=['Country name', 'Year'])

data.sort_values(by = 'Year', ascending = True)

data.sort_values( by=['Country name', 'Year'],
                ascending =[False, True]
               )

# Sorting - data.sort_index()
data.sort_index() # For ascending order
data.sort_index(ascending= False) # for decending order

# Filtering -- [columns] When we want to look at only one or multiple columns.

# selecting one columns

# These Both will provide the same results 
data['Year'].head(5) # Or
data.Year.head(10)


# Selecting the multiple columns:

#data[['Country name','Life Ladder']].sample(5)



# Filtering --- [Rows]  Rows in Pandas are selected by Index

   # iloc --- Allows selecting rows by position

# iloc- selecting one row:

       #data.iloc[row_number (,col_numbeer)]
    
data.iloc[10]
data.iloc[10,2]


# iloc --- Selecting Multiple Rows
    #data.iloc[startrow:end_row, start_column:end:column]
    
data.iloc[903:907]
data.iloc[903:907, 0:3]
# loc: 
    # data.loc as opposed to iloc allows selecting rows(and columns)
    #bY:
        # 1- label/index or 
        # 2- with a boolean/ conditional lookup
        
data.set_index('Country name', inplace = True)
data.sample(6)
# Out:
#               Year  Life Ladder  Log GDP per capita  Social support  \
# Country name
# Bolivia       2017     5.650553            8.837221        0.778662
# El Salvador   2011     4.741295            8.781317        0.731278
# Ecuador       2009     6.021803            9.125170        0.779398
# Luxembourg    2014     6.891127           11.447376        0.875469
# Iraq          2014     4.541502            9.604973        0.725151
# Malta         2011     6.154718           10.261808        0.922640
#
#               Healthy life expectancy at birth  Freedom to make life choices  \
# Country name
# Bolivia                              63.299999                      0.883905
# El Salvador                          64.400002                      0.747246
# Ecuador                              66.620003                      0.736881
# Luxembourg                           72.419998                      0.937988
# ...

# %%
data.index
# Out:
# Index(['Afghanistan', 'Afghanistan', 'Afghanistan', 'Afghanistan',
#        'Afghanistan', 'Afghanistan', 'Afghanistan', 'Afghanistan',
#        'Afghanistan', 'Afghanistan',
#        ...
#        'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe',
#        'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe'],
#       dtype='object', name='Country name', length=1704)

# %%
# loc - Selecting row(s) by one index label:

     # data.loc[index_label (,col_label)]
    
data.loc['India']
# Out:
#               Year  Life Ladder  Log GDP per capita  Social support  \
# Country name
# India         2006     5.348259            8.137376        0.707318
# India         2007     5.026793            8.215757        0.568993
# India         2008     5.145833            8.239232        0.683593
# India         2009     4.521518            8.306424        0.652852
# India         2010     4.989277            8.390427        0.604810
# ...            ...          ...                 ...             ...
# India         2014     4.424379            8.591399        0.621467
# India         2015     4.342079            8.658113        0.610133
# India         2016     4.179177            8.715343        0.613529
# India         2017     4.046111            8.768212        0.606767
# India         2018     3.818069            8.830280        0.638052
#
#               Healthy life expectancy at birth  Freedom to make life choices  \
# Country name
# ...

# %%
# loc - Selecting rows and a column by index label and column label:

data.loc['United States', 'Life Ladder']
# Out:
# Country name
# United States    7.181794
# United States    7.512688
# United States    7.280386
# United States    7.158032
# United States    7.163616
#                    ...
# United States    7.151114
# United States    6.863947
# United States    6.803600
# United States    6.991759
# United States    6.882685
# Name: Life Ladder, Length: 13, dtype: float64

# %%
# loc -- selecting row(s) by multiple index labels:
data.loc[['United States', 'Germany']].sample(5)
# Out:
#                Year  Life Ladder  Log GDP per capita  Social support  \
# Country name
# Germany        2018     7.118364           10.730945        0.919763
# Germany        2012     6.702362           10.664809        0.926407
# United States  2009     7.158032           10.790511        0.911794
# United States  2006     7.181794           10.831686        0.964572
# Germany        2016     6.873763           10.701712        0.906029
#
#                Healthy life expectancy at birth  Freedom to make life choices  \
# Country name
# Germany                               72.199997                      0.876888
# Germany                               71.059998                      0.904440
# United States                         68.540001                      0.830684
# United States                         68.059998                      0.911496
# Germany                               71.599998                      0.870515
#
# ...

# %%
# loc -- selecting rows and columns by multiple index labels:


data.loc[
    ['Germany', 'United States'],
    ['Year', 'Life Ladder']
].sample(5)
# Out:
#                Year  Life Ladder
# Country name
# United States  2018     6.882685
# United States  2017     6.991759
# Germany        2011     6.621312
# United States  2012     7.026227
# Germany        2017     7.074325

# %%
# loc -- selecting row(s) by a range of index labes:

data.loc[
    'Denmark':'Germany',
    ['Year', 'Life Ladder']
].sample(5)
# Out:
#               Year  Life Ladder
# Country name
# Ecuador       2012     5.960716
# Ethiopia      2012     4.561169
# Germany       2007     6.416820
# Estonia       2018     6.091302
# Georgia       2013     4.348921

# %%
# loc --- boolean/ conditional lookup
# We use || df.loc[overlay]

from numpy.random import randint
index = ['A', 'B', 'A', 'D']

## craete dummy DataFrame ##

df = pd.DataFrame(
    index = index, 
    data = {
        'values':randint(10, size= len(index))
})
print('DataFrame: ')
print(df)
# Out:
# DataFrame:
#    values
# A       7
# B       9
# A       5
# D       9

# %%
##  Create dummy overlay ##
overlay = pd.Series(
    index = index,
    data= [True, False, True, False]
)
print('\nOverlay:')
print(overlay)
# Out:
# Overlay:
# A     True
# B    False
# A     True
# D    False
# dtype: bool

# %%
##  Select only true Rows ##
print('\nMasked DataFrame:')
print(df.loc[overlay])
# Out:
# Masked DataFrame:
#    values
# A       7
# A       5

# %%
#  Boolean Mask

data['Life Ladder'] > 4
# Out:
# Country name
# Afghanistan    False
# Afghanistan     True
# Afghanistan     True
# Afghanistan    False
# Afghanistan    False
#                ...
# Zimbabwe        True
# Zimbabwe       False
# Zimbabwe       False
# Zimbabwe       False
# Zimbabwe       False
# Name: Life Ladder, Length: 1704, dtype: bool

# %%
# Option 1 
data.loc[data['Life Ladder'] > 4]

# Alternative

condition = data['Life Ladder'] > 4
data.loc[condition]
# Out:
#               Year  Life Ladder  Log GDP per capita  Social support  \
# Country name
# Afghanistan   2009     4.401778            7.333790        0.552308
# Afghanistan   2010     4.758381            7.386629        0.539075
# Afghanistan   2016     4.220169            7.497038        0.559072
# Albania       2007     4.634252            9.077331        0.821372
# Albania       2009     5.485470            9.161638        0.833047
# ...            ...          ...                 ...             ...
# Zimbabwe      2010     4.681570            7.296330        0.856638
# Zimbabwe      2011     4.845642            7.418864        0.864694
# Zimbabwe      2012     4.955101            7.534424        0.896476
# Zimbabwe      2013     4.690188            7.565154        0.799274
# Zimbabwe      2014     4.184451            7.562753        0.765839
#
#               Healthy life expectancy at birth  Freedom to make life choices  \
# Country name
# ...

# %%
life_condition = data['Life Ladder'] > 4
year_condition = data['Year'] > 2014
gen_condition = data['Generosity'] > .2

data.loc[life_condition & year_condition & gen_condition]
# Out:
#                 Year  Life Ladder  Log GDP per capita  Social support  \
# Country name
# Australia       2015     7.309061           10.690199        0.951862
# Australia       2016     7.250080           10.703098        0.942334
# Australia       2017     7.257038           10.706581        0.949958
# Bhutan          2015     5.082129            8.954588        0.847574
# Cambodia        2015     4.162165            8.098932        0.728610
# ...              ...          ...                 ...             ...
# United Kingdom  2018     7.233445           10.596948        0.928484
# United States   2015     6.863947           10.878154        0.903571
# Uzbekistan      2015     5.972364            8.648263        0.968225
# Uzbekistan      2016     5.892539            8.705982        0.945102
# Uzbekistan      2018     6.205460            8.773365        0.920821
#
#                 Healthy life expectancy at birth  \
# Country name
# ...

# %%
# loc -- advanced conditional lookup with custom formulas

cond_year = data['Year'].apply(lambda x:x%3 == 0)
cond_america = data['Continent'].apply(lambda x: 'America' in x)

data[cond_year & cond_america]
# Out:
#               Year  Life Ladder  Log GDP per capita  Social support  \
# Country name
# Argentina     2007     6.073158            9.792596        0.862206
# Argentina     2010     6.441067            9.836924        0.926799
# Argentina     2013     6.582260            9.877256        0.909874
# Argentina     2016     6.427221            9.830088        0.882819
# Belize        2007     6.450644            8.974969        0.872267
# ...            ...          ...                 ...             ...
# Uruguay       2013     6.444465            9.866335        0.917280
# Uruguay       2016     6.171485            9.908158        0.900381
# Venezuela     2010     7.478455            9.713838        0.931576
# Venezuela     2013     6.552796            9.779354        0.896301
# Venezuela     2016     4.041115            9.534059        0.901949
#
#               Healthy life expectancy at birth  Freedom to make life choices  \
# Country name
# ...

# %%
pd.read_csv?

# %%
# Return the Maximum Column Wise
y = data.max()
y.head()
# Out:
# Country name          Zimbabwe
# Year                      2018
# Life Ladder            8.01893
# Log GDP per capita     11.7703
# Social support        0.987343
# dtype: object

# %%
# Return the Maximum Row-Wise

a =data.max(axis= 1)
a.head()
# Out:
# 0    2008.0
# 1    2009.0
# 2    2010.0
# 3    2011.0
# 4    2012.0
# dtype: float64

# %%
# Return The Minmum Column Wise
x = data.min()
x.head()
# Out:
# Country name          Afghanistan
# Year                         2005
# Life Ladder               2.66172
# Log GDP per capita         6.4572
# Social support           0.290184
# dtype: object

# %%
# Return The Minimum Row-Wise
z = data.min(axis=0)
z.head()
# Out:
# Country name          Afghanistan
# Year                         2005
# Life Ladder               2.66172
# Log GDP per capita         6.4572
# Social support           0.290184
# dtype: object

# %%
# Calling the sum on data

b = data.sum()
b.head()
# Out:
# Country name          AfghanistanAfghanistanAfghanistanAfghanistanAf...
# Year                                                            3429014
# Life Ladder                                                     9264.91
# Log GDP per capita                                              15456.8
# Social support                                                  1370.67
# dtype: object

# %%
# Mean/Median/Quantile

# Call Mean, Median, Or quantile 

data.mean()
# Out:
# Year                                               2012.332160
# Life Ladder                                           5.437155
# Log GDP per capita                                    9.222456
# Social support                                        0.810570
# Healthy life expectancy at birth                     63.111971
#                                                       ...
# Most people can be trusted, WVS round 1989-1993       0.283925
# Most people can be trusted, WVS round 1994-1998       0.249574
# Most people can be trusted, WVS round 1999-2004       0.268070
# Most people can be trusted, WVS round 2005-2009       0.264336
# Most people can be trusted, WVS round 2010-2014       0.237493
# Length: 25, dtype: float64

# %%
data.median()
# Out:
# Year                                               2012.000000
# Life Ladder                                           5.339557
# Log GDP per capita                                    9.406206
# Social support                                        0.833098
# Healthy life expectancy at birth                     65.000000
#                                                       ...
# Most people can be trusted, WVS round 1989-1993       0.292383
# Most people can be trusted, WVS round 1994-1998       0.229924
# Most people can be trusted, WVS round 1999-2004       0.232000
# Most people can be trusted, WVS round 2005-2009       0.198380
# Most people can be trusted, WVS round 2010-2014       0.193531
# Length: 25, dtype: float64

# %%
data.quantile(q=.8)
# Out:
# Year                                               2016.000000
# Life Ladder                                           6.497157
# Log GDP per capita                                   10.375623
# Social support                                        0.913667
# Healthy life expectancy at birth                     69.900002
#                                                       ...
# Most people can be trusted, WVS round 1989-1993       0.344666
# Most people can be trusted, WVS round 1994-1998       0.304498
# Most people can be trusted, WVS round 1999-2004       0.388611
# Most people can be trusted, WVS round 2005-2009       0.415082
# Most people can be trusted, WVS round 2010-2014       0.373906
# Name: 0.8, Length: 25, dtype: float64

# %% [markdown]
# # idxmin/ idxmax
# Will return the Index of the row where the first minimum/ maximum is found .However, it is only possible to call this on columns with some ordinality to them.

# %%
# We Exclude the Continent Column
data.iloc[:,:-1].idxmax()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-235e961946b9> in <module>
#       1 # We Exclude the Continent Column
# ----> 2 data.iloc[:,:-1].idxmax()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in idxmax(self, axis, skipna)
#    8099         """
#    8100         axis = self._get_axis_number(axis)
# -> 8101         indices = nanops.nanargmax(self.values, axis=axis, skipna=skipna)
#    8102         index = self._get_axis(axis)
#    8103         result = [index[i] if i >= 0 else np.nan for i in indices]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      65             if any(self.check(obj) for obj in obj_iter):
#      66                 msg = "reduction operation {name!r} not allowed for this dtype"
# ...
